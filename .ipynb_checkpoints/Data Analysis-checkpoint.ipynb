# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import missingno as msno

from collections import Counter

from typing import List
# Out:
# D:\Anaconda\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# D:\Anaconda\lib\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
# D:\Anaconda\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
df = pd.read_excel('for_analitics.xlsx')
df.head()
# Out:
#    case_id  trans_id              channel channel_op  TB platform  \
# 0     8200   8200001  Электронный кошелек   Интернет   7   Другое
# 1     6100   6100001  Электронный кошелек   Интернет   7   Другое
# 2     6100   6100007  Электронный кошелек   Интернет   7   Другое
# 3     6100   6100002  Электронный кошелек   Интернет   7   Другое
# 4     6100   6100005  Электронный кошелек   Интернет   7   Другое
#
#        product_type      trx_begin_case crm_case_created_case  \
# 0  Банковская карта 2021-11-01 06:57:19   2021-10-31 22:02:25
# 1  Банковская карта 2021-11-01 01:59:53   2021-10-31 22:38:47
# 2  Банковская карта 2021-11-01 02:05:08   2021-10-31 22:38:47
# 3  Банковская карта 2021-11-01 02:00:57   2021-10-31 22:38:47
# 4  Банковская карта 2021-11-01 02:03:45   2021-10-31 22:38:47
#
#                                            questions
# 0  {u'ТСТ Причина совершения операции': u'Продает...
# 1  {u'Тип мошенничества': u'FIN', u'ТСТ Вердикт':...
# 2  {u'Тип мошенничества': u'FIN', u'ТСТ Вердикт':...
# 3  {u'Тип мошенничества': u'FIN', u'ТСТ Вердикт':...
# 4  {u'Тип мошенничества': u'FIN', u'ТСТ Вердикт':...

# %%
df.dtypes
# Out:
# case_id                           int64
# trans_id                          int64
# channel                          object
# channel_op                       object
# TB                                int64
# platform                         object
# product_type                     object
# trx_begin_case           datetime64[ns]
# crm_case_created_case    datetime64[ns]
# questions                        object
# dtype: object

# %%
df['questions']
# Out:
# 0       {u'ТСТ Причина совершения операции': u'Продает...
# 1       {u'Тип мошенничества': u'FIN', u'ТСТ Вердикт':...
# 2       {u'Тип мошенничества': u'FIN', u'ТСТ Вердикт':...
# 3       {u'Тип мошенничества': u'FIN', u'ТСТ Вердикт':...
# 4       {u'Тип мошенничества': u'FIN', u'ТСТ Вердикт':...
#                               ...
# 8765    {u'Другое Вы сообщали персональную информацию?...
# 8766    {u'Другое Вы сообщали персональную информацию?...
# 8767    {u'Тип мошенничества': u'FIN', u'Кредит Вердик...
# 8768    {u'Другое Вы сообщали персональную информацию?...
# 8769    {u'Тип мошенничества': u'FIN', u'Кредит Вердик...
# Name: questions, Length: 8770, dtype: object

# %%
df.shape
# Out:
# (8770, 10)

# %% [markdown]
# # Missing values

# %%
msno.bar(df)
# Out:
# <AxesSubplot: >

# %%
df[df['channel'].isna()]['channel_op'].value_counts() 
#если канал куда было совершенно списание отсутсвует то заскамили с устройства самообслуживания(остальное выбросы)
# Out:
# Устройства самообслуживания    573
# ТСТ или Токен                    3
# СБОЛ                             1
# Name: channel_op, dtype: int64

# %%
df[df['questions'].isna()]['channel_op'].value_counts()
# Out:
# СБОЛ             18
# Токен             5
# ТСТ или Токен     3
# Другое            2
# Name: channel_op, dtype: int64

# %%
df[df['questions'].isna()]
# Out:
# 4644  Банковская карта 2021-11-03 00:42:19   2021-11-03 01:21:22       NaN
# 4645  Банковская карта 2021-11-03 00:37:54   2021-11-03 01:21:22       NaN
# 5411  Банковская карта 2021-11-03 16:45:02   2021-11-03 17:27:36       NaN
# 5412  Банковская карта 2021-11-03 16:44:01   2021-11-03 17:27:36       NaN
# 5665  Банковская карта 2021-11-01 00:35:46   2021-11-03 20:50:11       NaN
# 5666  Банковская карта 2021-11-01 00:44:52   2021-11-03 20:50:11       NaN
# 5667  Банковская карта 2021-11-01 11:51:22   2021-11-03 20:50:11       NaN
# 5668  Банковская карта 2021-11-03 12:05:48   2021-11-03 20:50:11       NaN
# 5669  Банковская карта 2021-11-01 11:51:26   2021-11-03 20:50:11       NaN
# 5670  Банковская карта 2021-11-01 00:44:57   2021-11-03 20:50:11       NaN
# 5671  Банковская карта 2021-11-01 00:35:56   2021-11-03 20:50:11       NaN
# 5672  Банковская карта 2021-11-01 13:23:50   2021-11-03 20:50:11       NaN
# 5748  Банковская карта 2021-11-03 20:30:04   2021-11-03 22:26:19       NaN
# 8160  Банковская карта 2021-11-06 02:31:04   2021-11-06 11:10:50       NaN
# 8161  Банковская карта 2021-11-05 02:42:05   2021-11-06 11:10:50       NaN

# %%
df['questions']=df['questions'].fillna('НетДанных')

# %% [markdown]
# # EDA

# %%
df['channel'].value_counts()
# Out:
# Иное                   2444
# Снятие наличных        2026
# Карта другого Банка    1405
# Карта Сбербанка        1289
# Электронный кошелек     738
# Номер телефона          146
# ТСТ                     119
# Счет                     25
# Платежный счет            1
# Name: channel, dtype: int64

# %%
df['case_id'].value_counts() #всего 100 случаев
# Out:
# 6700    152
# 2500    149
# 5300    132
# 6900    126
# 7000    123
#        ...
# 7100     57
# 1300     54
# 8000     54
# 100      50
# 7900     43
# Name: case_id, Length: 100, dtype: int64

# %%
df[df['case_id'] == 9600].head(3)
# Out:
#      case_id  trans_id              channel channel_op  TB platform  \
# 31      9600   9600001  Электронный кошелек   Интернет   7   Другое
# 175     9600   9600001  Карта другого Банка       СБОЛ   5       МП
# 182     9600   9600003  Электронный кошелек   Интернет   7   Другое
#
#          product_type      trx_begin_case crm_case_created_case  \
# 31   Банковская карта 2021-11-01 01:06:22   2021-11-01 01:13:06
# 175  Банковская карта 2021-11-01 00:10:57   2021-11-01 06:12:16
# 182  Банковская карта 2021-11-01 03:09:15   2021-11-01 06:31:33
#
#                                              questions
# 31   {u'Тип мошенничества': u'FIN', u'ТСТ Вердикт':...
# 175  {u'СБОЛ. Схема мошенничества': u'Воспользовали...
# 182  {u'Тип мошенничества': u'FIN', u'ТСТ Вердикт':...

# %%
(df.groupby('case_id')['trx_begin_case'].max()-df.groupby('case_id')['trx_begin_case'].min()).describe()
#у нас данные скама за 4-6 дня
# Out:
# count                          100
# mean        5 days 12:37:48.030000
# std      0 days 09:16:35.253051486
# min                3 days 19:25:01
# 25%         5 days 10:25:57.750000
# 50%                5 days 14:42:17
# Name: crm_case_created_case, Length: 100, dtype: timedelta64[ns]

# %%
df.groupby('case_id')['crm_case_created_case'].describe(datetime_is_numeric = True)
# Out:
#         count                           mean                  min  \
# case_id
# 0          89  2021-11-02 23:01:21.853932544  2021-11-01 01:29:05
# 100        50  2021-11-03 09:55:47.939999744  2021-11-01 08:44:25
# 200        92  2021-11-03 19:04:39.923913216  2021-11-01 09:14:16
# 300        98  2021-11-03 00:17:23.387755008  2021-11-01 02:09:49
# 400        83  2021-11-03 14:07:11.289156352  2021-11-01 01:06:10
# ...       ...                            ...                  ...
# 9500       78  2021-11-03 15:27:14.564102912  2021-11-01 01:01:01
# 9600       80     2021-11-03 21:40:44.100000  2021-11-01 01:13:06
# 9700       98  2021-11-03 08:07:38.418367232  2021-11-01 08:50:47
# 9800       90            2021-11-03 20:30:42  2021-11-01 05:51:38
# 9900      114  2021-11-03 18:11:43.324561664  2021-11-01 01:00:06
#
#                                    25%                         50%  \
# case_id
# 0                  2021-11-01 15:23:49         2021-11-02 20:19:03
# 100      2021-11-01 22:05:53.750000128  2021-11-03 06:43:27.500000
# 200         2021-11-02 16:46:47.500000         2021-11-03 13:51:33
# 300      2021-11-01 13:53:02.249999872         2021-11-02 18:42:01
# 400                2021-11-02 17:32:26         2021-11-03 06:16:47
# ...                                ...                         ...
# 9500               2021-11-02 18:55:24         2021-11-03 13:35:21
# 9600               2021-11-02 17:37:55  2021-11-03 01:00:54.500000
# 9700               2021-11-01 14:15:38         2021-11-02 19:34:21
# 9800        2021-11-02 18:23:07.500000         2021-11-03 12:37:04
# 9900               2021-11-02 18:50:31         2021-11-04 06:29:30
#
#                                    75%                  max
# case_id
# 0                  2021-11-03 16:36:45  2021-11-08 10:43:20
# 100                2021-11-04 11:00:24  2021-11-08 09:16:54
# 200         2021-11-05 01:07:40.500000  2021-11-08 09:37:26
# 300      2021-11-03 21:46:59.750000128  2021-11-08 08:49:55
# 400         2021-11-04 16:43:33.500000  2021-11-07 16:39:04
# ...                                ...                  ...
# 9500               2021-11-04 20:29:02  2021-11-06 11:38:34
# 9600        2021-11-05 05:35:41.500000  2021-11-08 16:19:40
# 9700               2021-11-04 21:43:28  2021-11-08 16:02:46
# 9800               2021-11-04 22:00:57  2021-11-08 13:51:51
# 9900               2021-11-04 13:19:37  2021-11-08 14:40:32
#
# [100 rows x 7 columns]

# %%
df.groupby('case_id')['trans_id'].count().mean() # в среднем в каждом кейсе было совершенно 87-88 транзакций
# Out:
# 87.7

# %%
df.groupby('case_id')['trans_id'].count().std()
# Out:
# 18.75654767829306

# %%
def plot_bar(columns):
    for column in columns:
        plt.figure(figsize = (19,8))
        plt.bar(df[column].value_counts().index,df[column].value_counts().values)
        plt.title(column)
        plt.show()

# %%
plot_bar(['channel','channel_op','platform','product_type'])

# %%
sns.boxplot(data = df.groupby('case_id')['trans_id'].count(),orient = 'h')
# Out:
# <AxesSubplot: >

# %%
outliers = df.groupby('case_id')['trans_id'].count()
q75, q25 = np.percentile(outliers, [75 ,25])
iqr = q75 - q25
outliers.where((outliers <= q25 - 1.5*iqr ) | (outliers >= q75 + 1.5*iqr )).fillna(0).values.nonzero()[0]*100 #индексы выбросов
# Out:
# array([2500, 5300, 6700, 6900, 7900], dtype=int64)

# %%
df['time_to_react'] = abs(df['crm_case_created_case']-df['trx_begin_case'])
df
# Out:
#       case_id  trans_id              channel          channel_op  TB platform  \
# 0        8200   8200001  Электронный кошелек            Интернет   7   Другое
# 1        6100   6100001  Электронный кошелек            Интернет   7   Другое
# 2        6100   6100007  Электронный кошелек            Интернет   7   Другое
# 3        6100   6100002  Электронный кошелек            Интернет   7   Другое
# 4        6100   6100005  Электронный кошелек            Интернет   7   Другое
# ...       ...       ...                  ...                 ...  ..      ...
# 8765     5800   5800001                 Иное              Другое   4   Другое
# 8766     5800   5800002                 Иное              Другое   4   Другое
# 8767     3100   3100001      Карта Сбербанка  Зачисление кредита   4   Другое
# 8768     9700   9700001                 Иное              Другое   4   Другое
# 8769     9600   9600001                 Иное  Зачисление кредита   4   Другое
#
#           product_type      trx_begin_case crm_case_created_case  \
# 0     Банковская карта 2021-11-01 06:57:19   2021-10-31 22:02:25
# 1     Банковская карта 2021-11-01 01:59:53   2021-10-31 22:38:47
# 2     Банковская карта 2021-11-01 02:05:08   2021-10-31 22:38:47
# 3     Банковская карта 2021-11-01 02:00:57   2021-10-31 22:38:47
# 4     Банковская карта 2021-11-01 02:03:45   2021-10-31 22:38:47
# ...                ...                 ...                   ...
# 8765  Банковская карта 2021-11-03 12:37:20   2021-11-08 15:50:50
# 8766  Банковская карта 2021-11-03 12:42:12   2021-11-08 15:50:50
# 8767  Банковская карта 2021-11-06 13:34:58   2021-11-08 15:55:11
# 8768  Банковская карта 2021-11-04 15:06:34   2021-11-08 16:02:46
# 8769  Банковская карта 2021-11-05 12:07:52   2021-11-08 16:19:40
#
#                                               questions   time_to_react
# 0     {u'ТСТ Причина совершения операции': u'Продает... 0 days 08:54:54
# 1     {u'Тип мошенничества': u'FIN', u'ТСТ Вердикт':... 0 days 03:21:06
# 2     {u'Тип мошенничества': u'FIN', u'ТСТ Вердикт':... 0 days 03:26:21
# 3     {u'Тип мошенничества': u'FIN', u'ТСТ Вердикт':... 0 days 03:22:10
# 4     {u'Тип мошенничества': u'FIN', u'ТСТ Вердикт':... 0 days 03:24:58
# ...                                                 ...             ...
# 8765  {u'Другое Вы сообщали персональную информацию?... 5 days 03:13:30
# 8766  {u'Другое Вы сообщали персональную информацию?... 5 days 03:08:38
# 8767  {u'Тип мошенничества': u'FIN', u'Кредит Вердик... 2 days 02:20:13
# 8768  {u'Другое Вы сообщали персональную информацию?... 4 days 00:56:12
# 8769  {u'Тип мошенничества': u'FIN', u'Кредит Вердик... 3 days 04:11:48
#
# [8770 rows x 11 columns]

# %%
df.head()
# Out:
#    case_id  trans_id              channel channel_op  TB platform  \
# 8765  {u'Другое Вы сообщали персональную информацию?... 5 days 03:13:30
# 8766  {u'Другое Вы сообщали персональную информацию?... 5 days 03:08:38
# 8767  {u'Тип мошенничества': u'FIN', u'Кредит Вердик... 2 days 02:20:13
# 8768  {u'Другое Вы сообщали персональную информацию?... 4 days 00:56:12
# 8769  {u'Тип мошенничества': u'FIN', u'Кредит Вердик... 3 days 04:11:48
#
# [8770 rows x 11 columns]

# %%
df['text_splitted'] = df['questions'].apply(lambda x:x.split(' '))
df['text_splitted']
# Out:
# 0       [{u'ТСТ, Причина, совершения, операции':, u'Пр...
# 1       [{u'Тип, мошенничества':, u'FIN',, u'ТСТ, Верд...
# 2       [{u'Тип, мошенничества':, u'FIN',, u'ТСТ, Верд...
# 3       [{u'Тип, мошенничества':, u'FIN',, u'ТСТ, Верд...
# 4       [{u'Тип, мошенничества':, u'FIN',, u'ТСТ, Верд...
#                               ...
# 8765    [{u'Другое, Вы, сообщали персональную, информа...
# 8766    [{u'Другое, Вы, сообщали персональную, информа...
# 8767    [{u'Тип, мошенничества':, u'FIN',, u'Кредит, В...
# 8768    [{u'Другое, Вы, сообщали персональную, информа...
# 8769    [{u'Тип, мошенничества':, u'FIN',, u'Кредит, В...
# Name: text_splitted, Length: 8770, dtype: object

# %%
words = []
for i in df['text_splitted']:
    for j in i:
        w = ''
        for k in j:
            if k not in "u:,'{}[]":
                w+=k
        words.append(w)
len(words),words[:10]
# Out:
# (374812,
#  ['ТСТ',
#   'Причина',
#   'совершения',
#   'операции',
#   'Продает',
#   'или',
#   'покупает',
#   'товар/услугу',
#   'черезИнтернет',
#   'ТСТ'])

# %%
word_amount = Counter(words)
word_amount.most_common()[:15]
# Out:
# [('ТСТ', 22343),
#  ('мошенничества', 17654),
#  ('СБОЛ', 14078),
#  ('0', 12590),
#  ('Вы', 10728),
#  ('с', 9910),
#  ('3', 9674),
#  ('или', 9582),
#  ('Вердикт', 8920),
#  ('Схема', 8918),
#  ('Тип', 8736),
#  ('FIN', 8734),
#  ('Воспользовались', 8311),
#  ('лица', 8311),
#  ('без', 8311)]

# %%
word_freq = np.array(list(word_amount.values()))
word_freq = word_freq / np.sum(word_freq) #вероятности слов
#np.max(word_freq),list(word_amount.keys())[np.argmax(word_freq)]
word_prob = dict(zip(word_amount.keys(),word_freq)) # dict[word] = values , словарь слово -> вероятность

# %%
df
# Out:
#       case_id  trans_id              channel          channel_op  TB platform  \
# 0        8200   8200001  Электронный кошелек            Интернет   7   Другое
# 1        6100   6100001  Электронный кошелек            Интернет   7   Другое
# 2        6100   6100007  Электронный кошелек            Интернет   7   Другое
# 3        6100   6100002  Электронный кошелек            Интернет   7   Другое
# 4        6100   6100005  Электронный кошелек            Интернет   7   Другое
# ...       ...       ...                  ...                 ...  ..      ...
# 8765     5800   5800001                 Иное              Другое   4   Другое
# 8766     5800   5800002                 Иное              Другое   4   Другое
# 8767     3100   3100001      Карта Сбербанка  Зачисление кредита   4   Другое
# 8768     9700   9700001                 Иное              Другое   4   Другое
# 8769     9600   9600001                 Иное  Зачисление кредита   4   Другое
#
#           product_type      trx_begin_case crm_case_created_case  \
# 0     Банковская карта 2021-11-01 06:57:19   2021-10-31 22:02:25
# 1     Банковская карта 2021-11-01 01:59:53   2021-10-31 22:38:47
# 2     Банковская карта 2021-11-01 02:05:08   2021-10-31 22:38:47
# 3     Банковская карта 2021-11-01 02:00:57   2021-10-31 22:38:47
# 4     Банковская карта 2021-11-01 02:03:45   2021-10-31 22:38:47
# ...                ...                 ...                   ...
# 8765  Банковская карта 2021-11-03 12:37:20   2021-11-08 15:50:50
# 8766  Банковская карта 2021-11-03 12:42:12   2021-11-08 15:50:50
# 8767  Банковская карта 2021-11-06 13:34:58   2021-11-08 15:55:11
# 8768  Банковская карта 2021-11-04 15:06:34   2021-11-08 16:02:46
# 8769  Банковская карта 2021-11-05 12:07:52   2021-11-08 16:19:40
#
#                                               questions   time_to_react  \
# 0     {u'ТСТ Причина совершения операции': u'Продает... 0 days 08:54:54
# 1     {u'Тип мошенничества': u'FIN', u'ТСТ Вердикт':... 0 days 03:21:06
# 2     {u'Тип мошенничества': u'FIN', u'ТСТ Вердикт':... 0 days 03:26:21
# 3     {u'Тип мошенничества': u'FIN', u'ТСТ Вердикт':... 0 days 03:22:10
# 4     {u'Тип мошенничества': u'FIN', u'ТСТ Вердикт':... 0 days 03:24:58
# ...                                                 ...             ...
# 8765  {u'Другое Вы сообщали персональную информацию?... 5 days 03:13:30
# 8766  {u'Другое Вы сообщали персональную информацию?... 5 days 03:08:38
# 8767  {u'Тип мошенничества': u'FIN', u'Кредит Вердик... 2 days 02:20:13
# 8768  {u'Другое Вы сообщали персональную информацию?... 4 days 00:56:12
# 8769  {u'Тип мошенничества': u'FIN', u'Кредит Вердик... 3 days 04:11:48
#
#                                           text_splitted
# 0     [{u'ТСТ, Причина, совершения, операции':, u'Пр...
# 1     [{u'Тип, мошенничества':, u'FIN',, u'ТСТ, Верд...
# 2     [{u'Тип, мошенничества':, u'FIN',, u'ТСТ, Верд...
# 3     [{u'Тип, мошенничества':, u'FIN',, u'ТСТ, Верд...
# 4     [{u'Тип, мошенничества':, u'FIN',, u'ТСТ, Верд...
# ...                                                 ...
# 8765  [{u'Другое, Вы, сообщали персональную, информа...
# 8766  [{u'Другое, Вы, сообщали персональную, информа...
# 8767  [{u'Тип, мошенничества':, u'FIN',, u'Кредит, В...
# 8768  [{u'Другое, Вы, сообщали персональную, информа...
# 8769  [{u'Тип, мошенничества':, u'FIN',, u'Кредит, В...
#
# [8770 rows x 12 columns]

# %%
def split_text(text: str) -> List[List[str]]:
    array = []
    text_split = text.split('u')[1:]
    for i in range(0,len(text_split),2):
        array.append(text_split[i:i+2])
    return array

# %%
df['text_parsed'] = df['questions'].apply(split_text) #text_parsed содержит массив,[axis = 0 вопросы;axis = 1 ответы]
df.head(3)
# Out:
#    case_id  trans_id              channel channel_op  TB platform  \
# 0     8200   8200001  Электронный кошелек   Интернет   7   Другое
# 1     6100   6100001  Электронный кошелек   Интернет   7   Другое
# 2     6100   6100007  Электронный кошелек   Интернет   7   Другое
#
#        product_type      trx_begin_case crm_case_created_case  \
# 0  Банковская карта 2021-11-01 06:57:19   2021-10-31 22:02:25
# 1  Банковская карта 2021-11-01 01:59:53   2021-10-31 22:38:47
# 2  Банковская карта 2021-11-01 02:05:08   2021-10-31 22:38:47
#
#                                            questions   time_to_react  \
# 0  {u'ТСТ Причина совершения операции': u'Продает... 0 days 08:54:54
# 1  {u'Тип мошенничества': u'FIN', u'ТСТ Вердикт':... 0 days 03:21:06
# 2  {u'Тип мошенничества': u'FIN', u'ТСТ Вердикт':... 0 days 03:26:21
#
#                                        text_splitted  \
# 0  [{u'ТСТ, Причина, совершения, операции':, u'Пр...
# 1  [{u'Тип, мошенничества':, u'FIN',, u'ТСТ, Верд...
# 2  [{u'Тип, мошенничества':, u'FIN',, u'ТСТ, Верд...
#
#                                          text_parsed
# 0  [['ТСТ Причина совершения операции': , 'Продае...
# 1  [['Тип мошенничества': , 'FIN', ], ['ТСТ Верди...
# 2  [['Тип мошенничества': , 'FIN', ], ['ТСТ Верди...

# %%
split_text(df['questions'][0])
# Out:
# [["'ТСТ Причина совершения операции': ",
#   "'Продает или покупает товар/услугу черезИнтернет', "],
#  ["'ТСТ Вы совершили данную операцию самостоятельно?': ", "'1', "],
#  ["'Тип мошенничества': ", "'FIN', "],
#  ["'ТСТ Вердикт': ", "'Товар/услугу не получил, обман', "],
#  ["'ТСТ Схема мошенничества': ", "'Сам перевел'}"]]

# %%
df.head(3)
# Out:
#    case_id  trans_id              channel channel_op  TB platform  \
# 0     8200   8200001  Электронный кошелек   Интернет   7   Другое
# 1     6100   6100001  Электронный кошелек   Интернет   7   Другое
# 2     6100   6100007  Электронный кошелек   Интернет   7   Другое
#
#        product_type      trx_begin_case crm_case_created_case  \
# 0  Банковская карта 2021-11-01 06:57:19   2021-10-31 22:02:25
# 1  Банковская карта 2021-11-01 01:59:53   2021-10-31 22:38:47
# 2  Банковская карта 2021-11-01 02:05:08   2021-10-31 22:38:47
#
#                                            questions   time_to_react  \
# 0  {u'ТСТ Причина совершения операции': u'Продает... 0 days 08:54:54
# 1  {u'Тип мошенничества': u'FIN', u'ТСТ Вердикт':... 0 days 03:21:06
# 2  {u'Тип мошенничества': u'FIN', u'ТСТ Вердикт':... 0 days 03:26:21
#
#                                        text_splitted  \
# 0  [{u'ТСТ, Причина, совершения, операции':, u'Пр...
# 1  [{u'Тип, мошенничества':, u'FIN',, u'ТСТ, Верд...
# 2  [{u'Тип, мошенничества':, u'FIN',, u'ТСТ, Верд...
#
#                                          text_parsed
# 0  [['ТСТ Причина совершения операции': , 'Продае...
# 1  [['Тип мошенничества': , 'FIN', ], ['ТСТ Верди...
# 2  [['Тип мошенничества': , 'FIN', ], ['ТСТ Верди...
